# %% [markdown]
# ## 1- Data Card

# %%
# Make                Car Make
# Model               Car Model
# Year                Car Year (Marketing)
# Engine Fuel Type    Engine Fuel Type
# Engine HP           Engine Horse Power (HP)
# Engine Cylinders    Engine Cylinders
# Transmission Type   Transmission Type
# Driven_Wheels       Driven Wheels
# Number of Doors     Number of Doors
# Market Category     Market Category
# Vehicle Size        Size of Vehicle
# Vehicle Style       Type of Vehicle
# highway MPG         Highway MPG
# city mpg            City MPG
# Popularity          Popularity (Twitter)
# MSRP                Manufacturer Suggested Retail Price

# %% [markdown]
# ## Understand the Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# # Missing Value Handling

# %% [markdown]
# ## For Engine HP
# Engine HP (Horsepower)
#
# mean=249, median=227 → mean > median so the distribution is right_skewed
#
# std = 109.19 → high variability HP values are widely spread
#
# Range = 55 → 1001 → extreme outliers exist but its bec exotics cars so its not outliers
#
# -> Fill missing values with median, as data is skewed <-

# %%
df['Engine HP'].fillna(df['Engine HP'].median(), inplace=True)
# Out:
# C:\Users\amamr\AppData\Local\Temp\ipykernel_17788\217182256.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine HP'].fillna(df['Engine HP'].median(), inplace=True)

# %% [markdown]
# ## Engine Cylinders
#
# mean = 5.63 median = 6.0 → close values
#
# std= 1.78 → small std so it not vary
#
# Range = 0 → 16 0-> electric cars , 16 for exotics
#
# -> Fill missing values with median (6) <-

# %%
df['Engine Cylinders'].fillna(df['Engine Cylinders'].median(), inplace=True)
# Out:
# C:\Users\amamr\AppData\Local\Temp\ipykernel_17788\3427662301.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine Cylinders'].fillna(df['Engine Cylinders'].median(), inplace=True)

# %% [markdown]
# ## Number of Doors
#
# mean=3.43 , median = 4.0, Mode = 4
#
# std = 0.88 → small var and most of cars has 4 doors
#
# ->Decision: Fill missing values with mode (4) bec its categorical so i cant fill with mean <-

# %%
df['Number of Doors'].fillna(df['Number of Doors'].mode()[0], inplace=True)
# Out:
# C:\Users\amamr\AppData\Local\Temp\ipykernel_17788\4226697213.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Number of Doors'].fillna(df['Number of Doors'].mode()[0], inplace=True)

# %% [markdown]
# ## Engine Fuel Type  (string)

# %%
df['Engine Fuel Type'].unique()
# Out:
# array(['premium unleaded (required)', 'regular unleaded',
#        'premium unleaded (recommended)', 'flex-fuel (unleaded/E85)',
#        'diesel', 'electric',
#        'flex-fuel (premium unleaded recommended/E85)', 'natural gas',
#        'flex-fuel (premium unleaded required/E85)',
#        'flex-fuel (unleaded/natural gas)', nan], dtype=object)

# %%
df[df['Engine Fuel Type'].isnull()]
# Out:
#          Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df[df['Model']=='Verona']
# Out:
#          Make   Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004               NaN      155.0               6.0
# 11322  Suzuki  Verona  2004               NaN      155.0               6.0
# 11323  Suzuki  Verona  2004               NaN      155.0               6.0
# 11324  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11325  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11326  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11327  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11328  Suzuki  Verona  2006  regular unleaded      155.0               6.0
# 11329  Suzuki  Verona  2006  regular unleaded      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
# 11324         AUTOMATIC  front wheel drive              4.0             NaN
# 11325         AUTOMATIC  front wheel drive              4.0             NaN
# 11326         AUTOMATIC  front wheel drive              4.0             NaN
# 11327         AUTOMATIC  front wheel drive              4.0             NaN
# 11328         AUTOMATIC  front wheel drive              4.0             NaN
# 11329         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499
# 11324      Midsize         Sedan           25        18         481  19349
# 11325      Midsize         Sedan           25        18         481  21049
# 11326      Midsize         Sedan           25        18         481  17549
# 11327      Midsize         Sedan           25        18         481  20549
# 11328      Midsize         Sedan           25        17         481  20299
# 11329      Midsize         Sedan           25        17         481  18299

# %%
df['Engine Fuel Type'].mode()[0]
# Out:
# 'regular unleaded'

# %%
# Fill missing values in 'Engine Fuel Type' with the mode Bec it has 3 only missing values
df['Engine Fuel Type']=df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ## Market Category
# It has 31% Missing Data ,so I will drop it

# %%
# about 31% of rows are missing in that column so i will drop it
df.drop('Market Category',axis=1,inplace=True)

# %% [markdown]
# ## Model Handle
# It has so many unique values, so i will drop it

# %%
# It has so many unique values, so i will drop it
df.drop('Model',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# # Correltaion

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ## Price vs Age
# ### We wanted to see if there was a relationship between a cars age (Year) and its price (MSRP) and we discovered that the correlation is positive (0.23) This suggests that newer cars tend to be more expensive than older ones though the relationship is relatively weak
#
# ## Price vs HP
# ### We wanted to see if there was a relationship between a cars engine power (Horsepower) and its price (MSRP) and we discovered that the correlation is strongly positive (0.66) This indicates that cars with higher horsepower generally cost more

# %%
# bec it has high correlation with city mpg
#MSRP Is affected by Engine HP, Engine Cylinders
#Engine HP Is affected by Engine Cylinders
df.drop('highway MPG',axis=1,inplace=True)

# %% [markdown]
# # Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns to visualize
num_cols = ["Engine HP", "Engine Cylinders", "highway MPG", "city mpg", "MSRP"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Engine HP Outliers
# Engine HP & MSRP & Cylinders->  Outliers caused by luxury/supercars.
#
#  City MPG -> bad data

# %% [markdown]
# ### Imputation of outliers By inserting the mean value Because the median is 18 and the mean is 19.733255	 so Its Normal Distribution and STD is 6.7 so Its not Varying a lot so i will use mean

# %%
IQR_OF_CITY_MPG = df['city mpg'].quantile(0.75) - df['city mpg'].quantile(0.25)
Max_CITY_MPG = df['city mpg'].quantile(0.75) + 1.5 * IQR_OF_CITY_MPG
Max_CITY_MPG
df.loc[df["city mpg"] > Max_CITY_MPG, "city mpg"] = df['city mpg'].mean()
# Out:
# C:\Users\amamr\AppData\Local\Temp\ipykernel_17788\1790759363.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.73325499412456' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df["city mpg"] > Max_CITY_MPG, "city mpg"] = df['city mpg'].mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns to visualize
num_cols = ["Engine HP", "Engine Cylinders", "highway MPG", "city mpg", "MSRP"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
#  # Teaches the model about luxury vs normal

# %%
df["Car_Type"] = "Normal"
df.loc[(df["MSRP"] > 100000) | (df["Engine HP"] > 500), "Car_Type"] = "Luxury"
df["Car_Type"].value_counts()

# %% [markdown]
# # Extract Clean Data

# %%
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# # Feature Enginnering

# %%
df['Driven_Wheels'].unique()
# Out:
# array(['rear wheel drive', 'front wheel drive', 'all wheel drive',
#        'four wheel drive'], dtype=object)

# %%
df['Vehicle Size'].unique()
# Out:
# array(['Compact', 'Midsize', 'Large'], dtype=object)

# %%
df['Vehicle Style'].unique()
# Out:
# array(['Coupe', 'Convertible', 'Sedan', 'Wagon', '4dr Hatchback',
#        '2dr Hatchback', '4dr SUV', 'Passenger Minivan', 'Cargo Minivan',
#        'Crew Cab Pickup', 'Regular Cab Pickup', 'Extended Cab Pickup',
#        '2dr SUV', 'Cargo Van', 'Convertible SUV', 'Passenger Van'],
#       dtype=object)

# %%
Top_15_makes = df['Make'].value_counts().head(15).index
Top_15_makes
# i will keep only the top 15 makes and make the other ones all as others
df['Make'] = df['Make'].apply(lambda x: x if x in Top_15_makes else 'Other')
df.shape
# Out:
# (11914, 14)

# %%
# One-Hot Encoding Bec it has many categorical features And not Ordinal features
df = pd.get_dummies(df, columns=['Car_Type','Make','Engine Fuel Type','Driven_Wheels','Transmission Type', 'Vehicle Size', 'Vehicle Style'], drop_first=True)

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  city mpg  \
# 0  2011      335.0               6.0              2.0           26      19.0
# 1  2011      300.0               6.0              2.0           28      19.0
# 2  2011      300.0               6.0              2.0           28      20.0
# 3  2011      230.0               6.0              2.0           28      18.0
# 4  2011      230.0               6.0              2.0           28      18.0
# 5  2012      230.0               6.0              2.0           28      18.0
# 6  2012      300.0               6.0              2.0           26      17.0
# 7  2012      300.0               6.0              2.0           28      20.0
# 8  2012      230.0               6.0              2.0           28      18.0
# 9  2013      230.0               6.0              2.0           27      18.0
#
#    Popularity   MSRP  Make_BMW  Make_Cadillac  Make_Chevrolet  Make_Dodge  \
# 0        3916  46135      True          False           False       False
# 1        3916  40650      True          False           False       False
# 2        3916  36350      True          False           False       False
# 3        3916  29450      True          False           False       False
# 4        3916  34500      True          False           False       False
# 5        3916  31200      True          False           False       False
# 6        3916  44100      True          False           False       False
# 7        3916  39300      True          False           False       False
# 8        3916  36900      True          False           False       False
# 9        3916  37200      True          False           False       False
#
#    Make_Ford  Make_GMC  Make_Honda  Make_Infiniti  Make_Mazda  \
# 0      False     False       False          False       False
# 1      False     False       False          False       False
# 2      False     False       False          False       False
# 3      False     False       False          False       False
# 4      False     False       False          False       False
# 5      False     False       False          False       False
# 6      False     False       False          False       False
# 7      False     False       False          False       False
# 8      False     False       False          False       False
# 9      False     False       False          False       False
#
#    Make_Mercedes-Benz  Make_Nissan  Make_Other  Make_Suzuki  Make_Toyota  \
# 0               False        False       False        False        False
# 1               False        False       False        False        False
# 2               False        False       False        False        False
# 3               False        False       False        False        False
# 4               False        False       False        False        False
# 5               False        False       False        False        False
# 6               False        False       False        False        False
# 7               False        False       False        False        False
# 8               False        False       False        False        False
# 9               False        False       False        False        False
#
#    Make_Volkswagen  Engine Fuel Type_electric  \
# 0            False                      False
# 1            False                      False
# 2            False                      False
# 3            False                      False
# 4            False                      False
# 5            False                      False
# 6            False                      False
# 7            False                      False
# 8            False                      False
# 9            False                      False
#
#    Engine Fuel Type_flex-fuel (premium unleaded recommended/E85)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# 7                                              False
# 8                                              False
# 9                                              False
#
#    Engine Fuel Type_flex-fuel (premium unleaded required/E85)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# 7                                              False
# 8                                              False
# 9                                              False
#
#    Engine Fuel Type_flex-fuel (unleaded/E85)  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# 7                                      False
# 8                                      False
# 9                                      False
#
#    Engine Fuel Type_flex-fuel (unleaded/natural gas)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# 7                                              False
# 8                                              False
# 9                                              False
#
#    Engine Fuel Type_natural gas  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# 5                         False
# 6                         False
# 7                         False
# 8                         False
# 9                         False
#
#    Engine Fuel Type_premium unleaded (recommended)  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# 5                                            False
# 6                                            False
# 7                                            False
# 8                                            False
# 9                                            False
#
#    Engine Fuel Type_premium unleaded (required)  \
# 0                                          True
# 1                                          True
# 2                                          True
# 3                                          True
# 4                                          True
# 5                                          True
# 6                                          True
# 7                                          True
# 8                                          True
# 9                                          True
#
#    Engine Fuel Type_regular unleaded  Driven_Wheels_four wheel drive  \
# 0                              False                           False
# 1                              False                           False
# 2                              False                           False
# 3                              False                           False
# 4                              False                           False
# 5                              False                           False
# 6                              False                           False
# 7                              False                           False
# 8                              False                           False
# 9                              False                           False
#
#    Driven_Wheels_front wheel drive  Driven_Wheels_rear wheel drive  \
# 0                            False                            True
# 1                            False                            True
# 2                            False                            True
# 3                            False                            True
# 4                            False                            True
# 5                            False                            True
# 6                            False                            True
# 7                            False                            True
# 8                            False                            True
# 9                            False                            True
#
#    Transmission Type_AUTOMATIC  Transmission Type_DIRECT_DRIVE  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# 5                        False                           False
# 6                        False                           False
# 7                        False                           False
# 8                        False                           False
# 9                        False                           False
#
#    Transmission Type_MANUAL  Transmission Type_UNKNOWN  Vehicle Size_Large  \
# 0                      True                      False               False
# 1                      True                      False               False
# 2                      True                      False               False
# 3                      True                      False               False
# 4                      True                      False               False
# 5                      True                      False               False
# 6                      True                      False               False
# 7                      True                      False               False
# 8                      True                      False               False
# 9                      True                      False               False
#
#    Vehicle Size_Midsize  Vehicle Style_2dr SUV  Vehicle Style_4dr Hatchback  \
# 0                 False                  False                        False
# 1                 False                  False                        False
# 2                 False                  False                        False
# 3                 False                  False                        False
# 4                 False                  False                        False
# 5                 False                  False                        False
# 6                 False                  False                        False
# 7                 False                  False                        False
# 8                 False                  False                        False
# 9                 False                  False                        False
#
#    Vehicle Style_4dr SUV  Vehicle Style_Cargo Minivan  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
# 5                  False                        False
# 6                  False                        False
# 7                  False                        False
# 8                  False                        False
# 9                  False                        False
#
#    Vehicle Style_Cargo Van  Vehicle Style_Convertible  \
# 0                    False                      False
# 1                    False                       True
# 2                    False                      False
# 3                    False                      False
# 4                    False                       True
# 5                    False                      False
# 6                    False                       True
# 7                    False                      False
# 8                    False                       True
# 9                    False                       True
#
#    Vehicle Style_Convertible SUV  Vehicle Style_Coupe  \
# 0                          False                 True
# 1                          False                False
# 2                          False                 True
# 3                          False                 True
# 4                          False                False
# 5                          False                 True
# 6                          False                False
# 7                          False                 True
# 8                          False                False
# 9                          False                False
#
#    Vehicle Style_Crew Cab Pickup  Vehicle Style_Extended Cab Pickup  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
# 5                          False                              False
# 6                          False                              False
# 7                          False                              False
# 8                          False                              False
# 9                          False                              False
#
#    Vehicle Style_Passenger Minivan  Vehicle Style_Passenger Van  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# 5                            False                        False
# 6                            False                        False
# 7                            False                        False
# 8                            False                        False
# 9                            False                        False
#
#    Vehicle Style_Regular Cab Pickup  Vehicle Style_Sedan  Vehicle Style_Wagon
# 0                             False                False                False
# 1                             False                False                False
# 2                             False                False                False
# 3                             False                False                False
# 4                             False                False                False
# 5                             False                False                False
# 6                             False                False                False
# 7                             False                False                False
# 8                             False                False                False
# 9                             False                False                False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 57 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Year                                                           11914 non-null  int64
#  1   Engine HP                                                      11914 non-null  float64
#  2   Engine Cylinders                                               11914 non-null  float64
#  3   Number of Doors                                                11914 non-null  float64
#  4   highway MPG                                                    11914 non-null  int64
#  5   city mpg                                                       11914 non-null  float64
#  6   Popularity                                                     11914 non-null  int64
#  7   MSRP                                                           11914 non-null  int64
#  8   Make_BMW                                                       11914 non-null  bool
#  9   Make_Cadillac                                                  11914 non-null  bool
#  10  Make_Chevrolet                                                 11914 non-null  bool
#  11  Make_Dodge                                                     11914 non-null  bool
#  12  Make_Ford                                                      11914 non-null  bool
#  13  Make_GMC                                                       11914 non-null  bool
#  14  Make_Honda                                                     11914 non-null  bool
#  15  Make_Infiniti                                                  11914 non-null  bool
#  16  Make_Mazda                                                     11914 non-null  bool
#  17  Make_Mercedes-Benz                                             11914 non-null  bool
#  18  Make_Nissan                                                    11914 non-null  bool
#  19  Make_Other                                                     11914 non-null  bool
#  20  Make_Suzuki                                                    11914 non-null  bool
#  21  Make_Toyota                                                    11914 non-null  bool
#  22  Make_Volkswagen                                                11914 non-null  bool
#  23  Engine Fuel Type_electric                                      11914 non-null  bool
#  24  Engine Fuel Type_flex-fuel (premium unleaded recommended/E85)  11914 non-null  bool
#  25  Engine Fuel Type_flex-fuel (premium unleaded required/E85)     11914 non-null  bool
#  26  Engine Fuel Type_flex-fuel (unleaded/E85)                      11914 non-null  bool
#  27  Engine Fuel Type_flex-fuel (unleaded/natural gas)              11914 non-null  bool
#  28  Engine Fuel Type_natural gas                                   11914 non-null  bool
#  29  Engine Fuel Type_premium unleaded (recommended)                11914 non-null  bool
#  30  Engine Fuel Type_premium unleaded (required)                   11914 non-null  bool
#  31  Engine Fuel Type_regular unleaded                              11914 non-null  bool
#  32  Driven_Wheels_four wheel drive                                 11914 non-null  bool
#  33  Driven_Wheels_front wheel drive                                11914 non-null  bool
#  34  Driven_Wheels_rear wheel drive                                 11914 non-null  bool
#  35  Transmission Type_AUTOMATIC                                    11914 non-null  bool
#  36  Transmission Type_DIRECT_DRIVE                                 11914 non-null  bool
#  37  Transmission Type_MANUAL                                       11914 non-null  bool
#  38  Transmission Type_UNKNOWN                                      11914 non-null  bool
#  39  Vehicle Size_Large                                             11914 non-null  bool
#  40  Vehicle Size_Midsize                                           11914 non-null  bool
#  41  Vehicle Style_2dr SUV                                          11914 non-null  bool
#  42  Vehicle Style_4dr Hatchback                                    11914 non-null  bool
#  43  Vehicle Style_4dr SUV                                          11914 non-null  bool
#  44  Vehicle Style_Cargo Minivan                                    11914 non-null  bool
#  45  Vehicle Style_Cargo Van                                        11914 non-null  bool
#  46  Vehicle Style_Convertible                                      11914 non-null  bool
#  47  Vehicle Style_Convertible SUV                                  11914 non-null  bool
#  48  Vehicle Style_Coupe                                            11914 non-null  bool
#  49  Vehicle Style_Crew Cab Pickup                                  11914 non-null  bool
#  50  Vehicle Style_Extended Cab Pickup                              11914 non-null  bool
#  51  Vehicle Style_Passenger Minivan                                11914 non-null  bool
#  52  Vehicle Style_Passenger Van                                    11914 non-null  bool
#  53  Vehicle Style_Regular Cab Pickup                               11914 non-null  bool
#  54  Vehicle Style_Sedan                                            11914 non-null  bool
#  55  Vehicle Style_Wagon                                            11914 non-null  bool
#  56  Car_Type_Normal                                                11914 non-null  bool
# dtypes: bool(49), float64(4), int64(4)
# memory usage: 1.3 MB
